# %% [markdown]
# # DSCI 511-900 Final Project
# #### Name: Alec Peterson
# #### Email: ap3842@drexel.edu

# %% [markdown]
# # Import modules

# %%
# requests, json - for API calls
import requests
import json

# Pandas - for dataframes
import pandas as pd

# spaCy - for nlp
import spacy

# timeit - for timing operations
import timeit

# time - for pausing between loop iterations to adhere to API call rate limit
import time

import pyarrow as pa # For changing dataframes to Apache Arrow tables
import pyarrow.parquet as pq # For saving Arrow tables as Apache Parquet files

# %%
# Modify spacy pipeline to only include tokenizer and named entity recognition (ner)
nlp = spacy.load("en_core_web_sm", disable=["tagger", "parser"])

# %% [markdown]
# # Define functions

# %% [markdown]
# ## `gen_url(year_no, month_no)`
# __Make URL for API call to New York Times' Archive API__

# %%
# Define a function to generate a url given input year number (year_no) and month number (month_no, a number 1 through 12)
def gen_url(year_no, month_no):
    
    url = "https://api.nytimes.com/svc/archive/v1/{}/{}.json?api-key={api_key}".format(str(year_no),
                                                                                str(month_no),
                                                                                api_key = "jQd6lZrlLaHAN4oAvYIvGzkq6tGBYTXO") # api_key is unique to user. Please do not distribute.
    
    return url

# %% [markdown]
# ## `doc_df(docs)`
# __Iterate over document list (articles) and return a pandas dataframe__

# %%
def doc_df(docs):
    import pandas as pd
    from collections import defaultdict
    
    doc_keys = ["pub_date", "abstract", "web_url", 
                "lead_paragraph","document_type", "news_desk",
                "section_name", "type_of_material", "source", 
                "headline", "byline", "_id", 
                "word_count"]
        
    doc_dict = defaultdict(list)
        
    for key in doc_keys:
        for doc in docs:
            
            # headline is a dict
            if key == "headline":
                doc_dict[key].append(doc[key]["main"])
                
            # get "original" string instead of dealing with "person" dictionary which may not be present
            elif key == "byline":
                doc_dict[key].append(doc[key]["original"])
                
            # all other keys
            else:
                doc_dict[key].append(doc[key])
    
    return pd.DataFrame(doc_dict)

# %% [markdown]
# ## `parse_docs(year_no, month_no)`
# __Generate URL -> call API -> call doc_df() to generate dataframe__

# %%
def parse_docs(year_no, month_no):
    
    # Generate the url
    url = gen_url(year_no, month_no)
    response = requests.get(url)
    results = response.json()
    docs = results["response"]["docs"] # a list of documents, each item is a dictionary
    
    # Generate the dataframe
    df = doc_df(docs)
    
    return df

# %% [markdown]
# ## `make_df_NYTarchive(year_start, year_end)`
# __Iterate over every month for all years from year_start to year_end (exclusive), and return a large dataframe. Also prints time it takes to do so (~2 minutes / year)__

# %%
def make_df_NYTarchive(year_start, year_end):
    
    # Timer start
    start_time = timeit.default_timer()

    # Collect dataframes for each year and month, calling the parse_docs function
    df_list = []
    for year in range(year_start, year_end):
        for month in range(1, 13):
            # Start timer
            parse_time_start = timeit.default_timer()
            
            # Call parse_docs, then append the resulting dataframe to df_list
            df = parse_docs(year, month)
            df_list.append(df)
            
            # End timer
            parse_time_end = timeit.default_timer()
            
            # Wait at least 6 seconds between API calls
            parse_time_total = parse_time_end - parse_time_start
            if parse_time_total > 6:
                continue
            else:
                time.sleep(6 - parse_time_total)
    
    # Make a "big" dataframe combining the dataframes for each year-month's articles
    df_big = df_list[0]
    for i in range(1, len(df_list)):
        df_big = pd.concat([df_big, df_list[i]])
    
    ## Reindex the big dataframe
    df_big.index = pd.RangeIndex(len(df_big))
    
    ## Change pub_date to date, add "year" and "month" column
    df_big["pub_date"] = pd.to_datetime(df_big["pub_date"])
    df_big["pub_date"] = df_big["pub_date"].apply(lambda x: x.date())
    df_big["year"] = df_big["pub_date"].apply(lambda x: x.year)
    df_big["month"] = df_big["pub_date"].apply(lambda x: x.month)
    
    ## Reorder the columns
    df_big = df_big.loc[:, ["_id", "pub_date", "year", "month", "headline", "abstract", "lead_paragraph", "byline", 
                            "word_count", "document_type", "news_desk", "section_name", "type_of_material", "source", "web_url"]]
    
    '''
    ## Optional: Change specific text columns to dtype = "string[pyarrow]" for more efficient memory representation / downstream processing
    df_big["headline"] = df_big["headline"].astype("string[pyarrow]")
    df_big["abstract"] = df_big["abstract"].astype("string[pyarrow]")
    df_big["lead_paragraph"] = df_big["lead_paragraph"].astype("string[pyarrow]")
    '''
    
    # Timer elapsed
    elapsed = timeit.default_timer() - start_time
    print("Elapsed time: {} minutes".format(elapsed/60))
    return df_big

# %% [markdown]
# # Generate Desired Dataframe

# %% [markdown]
# Make a smaller "test" dataframe with only a year's worth of data...

# %%
df_test = make_df_NYTarchive(1990, 1991) # Should take ~2 minutes to run, will get all articles from 1990 up to 1991
# Out:
# Elapsed time: 1.592971148333333 minutes

# %% [markdown]
# <br>
# ...Or make a "big" dataframe with a decade's worth of data.

# %%
df_big = make_df_NYTarchive(1990, 2000) # Should take ~20 - 25 minutes to run, will get all articles from 1990 up to 2000

# %% [markdown]
# # Saving as .parquet file with `pyarrow`
#
# * Apache Parquet files (.parquet, https://parquet.apache.org/) are a columnar storage format that have more efficient storage and can be read in faster than the equivalent .csv file
# * Parquet files can be efficiently read and written in Python with the `pyarrow` package, which takes advantage of a language-independent in-memory columnar data Apache Arrow (https://arrow.apache.org/) format
#     * pandas can also read in Parquet files using `pandas.read_parquet()`, which is faster than pandas.read_csv() (by ~3x)
#
# A .csv for a decade's worth of data could be ~0.8 to ~1 gigabyte. Parquet is a more efficient storage format. Optionally, analyses maybe done with the more efficient in-memory Arrow representation through packages like `pyarrow`, `ibis`, or `polars`.

# %% [markdown]
# ## `save_as_parquet(year_start, year_end`
# __Call `make_df_NYTarchive()` and save the table as a .parquet file in local directory__

# %%
def save_as_parquet(year_start, year_end):
    import pyarrow as pa # import pyarrow
    import pyarrow.parquet as pq # shorten parquet module from pyarrow
    
    df_big = make_df_NYTarchive(year_start, year_end)
    
    table = pa.Table.from_pandas(df_big)
    pq.write_table(table ,"{}_to_{}.parquet".format(year_start, year_end))
    
    print("Dataframe saved as {}_to_{}.parquet".format(year_start, year_end))
    return df_big

# %% [markdown]
# # Generate `spaCy` doc objects for - headline, abstract, lead_paragraph

# %% [markdown]
# ## headline_docs, abstract_docs, lead_para_docs

# %%
print(nlp.pipeline) # Verify pipepline components
# Out:
# [('ner', <spacy.pipeline.pipes.EntityRecognizer object at 0x000001D8FC8C32E0>)]

# %% [markdown]
# ### Either operate on df_test (and reassign to df_big), df_big generated in earlier cell, or load .parquet file

# %%
# Run if using df_test from earlier cell i.e. importing only 1 year's worth of data
df_big = df_test

# %%
# If didn't want to wait for make_df_NYT_archive(), can load local .parquet file
df_big = pd.read_parquet("1990_to_2000.parquet") # Example...

# %% [markdown]
# ### Make list of spaCy doc objects with `nlp.pipe()`

# %%
# Make list of spaCy doc objects from text columns
headline_docs = list(nlp.pipe(df_big["headline"]))

abstract_docs = list(nlp.pipe(df_big["abstract"]))

lead_para_docs = list(nlp.pipe(df_big["lead_paragraph"]))


# nlp.pipe() allows multithreading with the n_process argument. For this task, using n_process = 2 gave 40-50% speed increase
# Using n_process = 3 or higher gave diminishing returns on my computer
'''
headline_docs = list(nlp.pipe(df_big["headline"], n_process=2))

abstract_docs = list(nlp.pipe(df_big["abstract"], n_process=2))

lead_para_docs = list(nlp.pipe(df_big["lead_paragraph"], n_process=2))
'''

# %% [markdown]
# ### Make a dictionary, `article_dict` containing article id, pub_date, headline, abstract, lead_paragraph, and associated lemmas and entities that will eventually become a dataframe

# %%
article_dict = {}
for i in range(len(df_big["_id"])):
    article_dict[df_big["_id"][i]] = {"pub_date": df_big["pub_date"][i],
                                  
                                      # headline and its tokens, and entities
                                      "headline": df_big["headline"][i],

                                      "lemmas_headline": [token.lemma_ for token in headline_docs[i] 
                                                          if not token.is_stop and not token.is_punct and not token.is_space and not token.like_num],
                                      "entities_headline": list(headline_docs[i].ents),

                                      # abstract and its tokens and entities
                                      "abstract": df_big["abstract"][i],

                                      "lemmas_abstract": [token.lemma_ for token in abstract_docs[i] 
                                                          if not token.is_stop and not token.is_punct and not token.is_space and not token.like_num],
                                      "entities_abstract": list(abstract_docs[i].ents),
                                      
                                      # lead paragraph and its tokens and entities
                                      "lead_paragraph": df_big["lead_paragraph"],
                                      
                                      "lemmas_lead_para": [token.lemma_ for token in lead_para_docs[i] 
                                                           if not token.is_stop and not token.is_punct and not token.is_space and not token.like_num],
                                      "entities_lead_para": list(lead_para_docs[i].ents)}

# %% [markdown]
# ## df2_big - turn `article_dict` into dataframe

# %%
df2_big = pd.DataFrame(article_dict).transpose()

# Make sure "pub_date" is a date
df2_big["pub_date"] = pd.to_datetime(df2_big["pub_date"])
df2_big["pub_date"] = df2_big["pub_date"].apply(lambda x: x.date())
                                     
df2_big.head()
# Out:
#                                                       pub_date  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  1990-01-01
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  1990-01-01
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3  1990-01-01
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad  1990-01-01
#
#                                                                                              headline  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                             Bridge
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236                           He Has Tyson On His Mind
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  For Dinkins, Pomp, Ceremony, Triumph And a Dre...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3  Army Doesn't Have to Compete With Marines;   W...
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad        Students Must Get to School and Back Safely
#
#                                                                                       lemmas_headline  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                           [Bridge]
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236                                      [Tyson, Mind]
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  [Dinkins, Pomp, Ceremony, Triumph, Dream, Real...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3               [Army, Compete, Marines, Need, Navy]
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                         [Students, School, Safely]
#
#                                                       entities_headline  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                   []
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236                   []
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  [(Dinkins), (Pomp)]
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3     [(Army), (Navy)]
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                   []
#
#                                                                                              abstract  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  LEAD: One of the many sad bridge stories of 19...
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  LEAD: THOSE on Donovan Ruddock's Christmas-car...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  LEAD: The walls of David N. Dinkins's borough ...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3                               LEAD: To the Editor:
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                               LEAD: To the Editor:
#
#                                                                                       lemmas_abstract  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  [LEAD, sad, bridge, story, concern, final, Aus...
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  [LEAD, Donovan, Ruddock, Christmas, card, list...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  [LEAD, wall, David, N., Dinkins, borough, pres...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3                                     [LEAD, Editor]
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                                     [LEAD, Editor]
#
#                                                                                     entities_abstract  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  [(One), (1989), (the, Australian, National, Te...
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  [(Donovan, Ruddock, 's), (Christmas), (this, y...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  [(David, N., Dinkins, 's), (dozens), (City, Ha...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3                                                 []
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                                                 []
#
#                                                                                        lead_paragraph  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  0        One of the many sad bridge stories of...
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  0        One of the many sad bridge stories of...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  0        One of the many sad bridge stories of...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3  0        One of the many sad bridge stories of...
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad  0        One of the many sad bridge stories of...
#
#                                                                                      lemmas_lead_para  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  [sad, bridge, story, concern, final, Australia...
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  [Donovan, Ruddock, Christmas, card, list, get,...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  [wall, David, N., Dinkins, borough, president,...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3                                           [Editor]
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                                           [Editor]
#
#                                                                                    entities_lead_para
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  [(One), (1989), (the, Australian, National, Te...
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  [(Donovan, Ruddock, 's), (Christmas), (this, y...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  [(David, N., Dinkins, 's), (dozens), (City, Ha...
# nyt://article/0da7cd16-c122-51c0-b392-2484ac4b7de3                                                 []
# nyt://article/0ecac4c0-3b20-5037-b395-475a416687ad                                                 []

# %% [markdown]
# ## `make_exploded_df(df, col_name)` - make df with row for each lemma or entity via df.explode()

# %%
def make_exploded_df(df, col_name):
    if col_name == "lemmas_headline" or "entities_headline":
        base_col = "headline"
    elif col_name == "lemmas_abstract" or "entities_abstract":
        base_col = "abstract"
    else:
        base_col = "lead_paragraph"
    
    df_exp = df.explode(column = col_name).loc[:, ["pub_date", base_col, col_name]]
    
    return df_exp

# %%
df_lems_headline = make_exploded_df(df2_big, "lemmas_headline")
df_lems_headline.head()
# Out:
#                                                       pub_date  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  1990-01-01
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236  1990-01-01
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  1990-01-01
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  1990-01-01
#
#                                                                                              headline  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                             Bridge
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236                           He Has Tyson On His Mind
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236                           He Has Tyson On His Mind
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  For Dinkins, Pomp, Ceremony, Triumph And a Dre...
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa  For Dinkins, Pomp, Ceremony, Triumph And a Dre...
#
#                                                    lemmas_headline
# nyt://article/065d970c-0342-5066-a441-f59423263e3d          Bridge
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236           Tyson
# nyt://article/0a0e2668-b979-56d1-b675-c7f521131236            Mind
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa         Dinkins
# nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5a0aa            Pomp

# %%
df_ents_abs = make_exploded_df(df2_big, "entities_abstract")
df_ents_abs.head()
# Out:
#                                                       pub_date headline  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
#
#                                                                                   entities_abstract
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                            (One)
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                           (1989)
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  (the, Australian, National, Team, Championship)
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                       (Canberra)
# nyt://article/065d970c-0342-5066-a441-f59423263e3d                                       (February)

# %%
df_ents_abs["entities_abstract"][2]
# Out:
# the Australian National Team Championship

# %%
df_lems_lead_para = make_exploded_df(df2_big, "lemmas_lead_para")
df_lems_lead_para.head()
# Out:
#                                                       pub_date headline  \
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d  1990-01-01   Bridge
#
#                                                    lemmas_lead_para
# nyt://article/065d970c-0342-5066-a441-f59423263e3d              sad
# nyt://article/065d970c-0342-5066-a441-f59423263e3d           bridge
# nyt://article/065d970c-0342-5066-a441-f59423263e3d            story
# nyt://article/065d970c-0342-5066-a441-f59423263e3d          concern
# nyt://article/065d970c-0342-5066-a441-f59423263e3d            final

# %%
df_big
# Out:
#                                                      _id    pub_date  year  \
# 0      nyt://article/065d970c-0342-5066-a441-f5942326...  1990-01-01  1990
# 1      nyt://article/0a0e2668-b979-56d1-b675-c7f52113...  1990-01-01  1990
# 2      nyt://article/0a71f8ee-d649-5ae8-9524-e2f1d6d5...  1990-01-01  1990
# 3      nyt://article/0da7cd16-c122-51c0-b392-2484ac4b...  1990-01-01  1990
# 4      nyt://article/0ecac4c0-3b20-5037-b395-475a4166...  1990-01-01  1990
# ...                                                  ...         ...   ...
# 98900  nyt://article/f4e78851-de2b-5d9e-9e08-c525ef53...  1990-12-31  1990
# 98901  nyt://article/f5d13149-6618-5d0e-855a-0b7fe93b...  1990-12-31  1990
# 98902  nyt://article/f627c63e-c7f8-59a4-bf1f-986774ae...  1990-12-31  1990
# 98903  nyt://article/fb863530-af68-54a8-a6b4-bb764a60...  1990-12-31  1990
# 98904  nyt://article/fc7b86d7-34d4-59f9-8af5-bddd4be7...  1990-12-31  1990
#
#        month                                           headline  \
# 0          1                                             Bridge
# 1          1                           He Has Tyson On His Mind
# 2          1  For Dinkins, Pomp, Ceremony, Triumph And a Dre...
# 3          1  Army Doesn't Have to Compete With Marines;   W...
# 4          1        Students Must Get to School and Back Safely
# ...      ...                                                ...
# 98900     12                          Canada-Korea A-Plant Pact
# 98901     12       Carlos Fuentes Trades His Pen for Television
# 98902     12  World Markets Begin 1991 Pressed by Problems o...
# 98903     12  Soviet Consumer Vigilantes Ferret Out Hoarded ...
# 98904     12  American Industry Faces the Challenge of Tough...
#
#                                                 abstract  \
# 0      LEAD: One of the many sad bridge stories of 19...
# 1      LEAD: THOSE on Donovan Ruddock's Christmas-car...
# 2      LEAD: The walls of David N. Dinkins's borough ...
# 3                                   LEAD: To the Editor:
# 4                                   LEAD: To the Editor:
# ...                                                  ...
# 98900    Canada's state-owned nuclear power company h...
# 98901    Carlos Fuentes is an uncontrollable wanderer...
# 98902    World stock markets begin 1991 facing the th...
# 98903    The secrets of the Faton Vegetable and Fruit...
# 98904    Robert C. Stempel  A New Team Spirit At Gene...
#
#                                           lead_paragraph  \
# 0      One of the many sad bridge stories of 1989 con...
# 1      THOSE on Donovan Ruddock's Christmas-card list...
# 2      The walls of David N. Dinkins's borough presid...
# 3                                         To the Editor:
# 4                                         To the Editor:
# ...                                                  ...
# 98900  Canada's state-owned nuclear power company has...
# 98901  Carlos Fuentes is an uncontrollable wanderer, ...
# 98902  World stock markets begin 1991 facing the thre...
# 98903  The secrets of the Faton Vegetable and Fruit S...
# 98904  Robert C. Stempel A New Team Spirit At General...
#
#                                                  byline  word_count  \
# 0                                      By Alan Truscott         411
# 1                                        By Phil Berger         199
# 2                                          By Don Terry        1233
# 3                                                               524
# 4                                                               363
# ...                                                 ...         ...
# 98900                                                AP         204
# 98901     By Alan Riding, Special To the New York Times        1402
# 98902                           By Jonathan Fuerbringer        1843
# 98903  By Esther B. Fein, Special To the New York Times        1355
# 98904                                 By Doron P. Levin         297
#
#       document_type          news_desk  section_name type_of_material  \
# 0           article  Metropolitan Desk      New York             News
# 1           article        Sports Desk        Sports             News
# 2           article  Metropolitan Desk      New York             News
# 3           article     Editorial Desk       Opinion           Letter
# 4           article     Editorial Desk       Opinion           Letter
# ...             ...                ...           ...              ...
# 98900       article     Financial Desk  Business Day             News
# 98901       article      Cultural Desk          Arts             News
# 98902       article     Financial Desk  Business Day             News
# 98903       article       Foreign Desk         World             News
# 98904       article     Financial Desk  Business Day             News
#
#                    source                                            web_url
# 0      The New York Times  https://www.nytimes.com/1990/01/01/nyregion/br...
# 1      The New York Times  https://www.nytimes.com/1990/01/01/sports/spor...
# 2      The New York Times  https://www.nytimes.com/1990/01/01/nyregion/fo...
# 3      The New York Times  https://www.nytimes.com/1990/01/01/opinion/l-a...
# 4      The New York Times  https://www.nytimes.com/1990/01/01/opinion/l-s...
# ...                   ...                                                ...
# 98900  The New York Times  https://www.nytimes.com/1990/12/31/business/th...
# 98901  The New York Times  https://www.nytimes.com/1990/12/31/arts/carlos...
# 98902  The New York Times  https://www.nytimes.com/1990/12/31/business/in...
# 98903  The New York Times  https://www.nytimes.com/1990/12/31/world/sovie...
# 98904  The New York Times  https://www.nytimes.com/1990/12/31/business/th...
#
# [98905 rows x 15 columns]
